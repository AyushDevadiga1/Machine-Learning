# %%
# Add imports at the top based on the requirements
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
import numpy as np

# %%
# We make our own classification dataset using make_classfication

X , y = make_classification(
                             n_samples=100, # No of rows
                             n_features=2, # No of columns
                             n_redundant=0, # No of redundant columns
                             n_classes=2, # No of labels for output
                             n_clusters_per_class=1, # No of clusters per label
                             n_informative=1, # No of useful features
                             hypercube=False, 
                             class_sep=10, # Seperation dist between the clusters
                             random_state=54 # Number for replicating this state
)

# Note : Experiment with random values to make sure we get a better grasp about each algorithm and their differences.

# %%
X.shape,y.shape # Shape of the dataset for X and y
# Out:
# ((100, 2), (100,))

# %%
# Now lets visualize the points
plt.figure(figsize=(10,5)) 
plt.scatter(X[:,0],X[:,1],c=y,s=50) # Plotting the X points 
plt.show()
# Note : Experiment with different values with this above block in a loop for experimenting the make_classfication function.

# %% [markdown]
# # Logistic Regression using Perceptron

# %% [markdown]
# ## Step function

# %%
# Now creating the perceptron from scratch for step function
class pereceptron:
    def __init__(self,learning_rate=0.1,epochs=1000):
        # Instantiate the objects with default values and None appropriately.
        self.lr = learning_rate 
        self.epochs = epochs
        self.coef = None
        self.intercept = None

        # Arrays for m and b in each iteration
        # This step is just done to calculate the slope and intercept here itself so it saves time for plotting the predicted 
        # line that will seperate classes.
        self.m = []
        self.b = []

    def step(self,z):
        # Step function is a function which returns 1 for any value greater than one and 0 for other cases .
        # This is a somewhat not proper and will be addresses later when we compare the models.
        return 1 if z>0 else 0
    
    def fit(self,X,y):
        X = np.insert(X,0,1,axis=1) # Creates a column for the coeffecients of w
        w = np.ones(X.shape[1]) # Creates a matrix (1 * n ) where n is the value passed

        # Now iterating over epochs times:
        for i in range(self.epochs):
            # As the formula : Wnew = Wold - lr*(y - y_hat)*X

            # First lets pick the random point index for the iteration
            j = np.random.randint(0,X.shape[0])

            # Second creating y_hat
            y_hat = self.step(np.dot(X[j],w)) # Call the step function so we can get values 0 or 1

            # Now lets update w (the matrix consisting of the intercept and the coeffecient) value . 
            w = w + self.lr*(y[j] - y_hat)*X[j]

         # We do this step to extract the coef and intercept which can be later be accessed as objects.
         # We do this outside loop to save computational cost (can be done inside if we are animating inside with plotting methods and libraries).
        self.coef = w[1:]
        self.intercept = w[0]
            
        # The process we did explicilty will be done here automatically
        self.m.append(-(w[1]/w[2])) 
        self.b.append(-(w[0]/w[1]))

        return f"Intercept : {w[0]}  Coeffecient : {w[1:]}"
    
    # Added special method to return the parameters slope and intercept
    def params(self):
        return self.m,self.b

# %%
prc = pereceptron() # Instantiate the perceptron

# %%
prc.fit(X,y) # fit the data
# Out:
# 'Intercept : 0.10000000000000014  Coeffecient : [0.02200575 0.83000259]'

# %%
# Now lets plot the line that is acting like a seperation boundary for classification
# For this lets first calculate m and b value

m = - ( prc.coef[0] / prc.coef[1] ) # m = - A/B
b = - ( prc.intercept / prc.coef[1] ) # b = - C/B

# %%
# Now making x and y values for the line equation
x_ip = np.linspace(-3,3,X.shape[0]) # (-y boundary, + y boundary ,X.shape[0])
y_ip = (m*x_ip)+ b  # y = m*x + b

# %%
# Plotting the same graph as above but with the line
plt.figure(figsize=(10,5))
plt.plot(x_ip,y_ip,c='r') # Plotting the line we created with the coef of m and b 
plt.scatter(X[:,0],X[:,1],c=y,s=100)
plt.ylim(-3,2) # Sets the y limit for both the axes
plt.show()
# If we run this program again and again with different we will find that this method is good but not perfect.
# To understand more we will use the LogisticRegression model of sci-kit learn to compare .

# %%
# Acessing m and b of each iteration
# Note this is just made for accessing and making animations using FuncAnimation for the above which maybe done in future
m ,b = (prc.params())

# %%
# Now lets compare this with the Logistic Regression and understand why this method is incomplete .
lor = LogisticRegression()

# %%
lor.fit(X,y) # Fitting the params
# Out:
# LogisticRegression()

# %%
lor.coef_,lor.intercept_ # Compare the intercept and coef with our model
# Out:
# (array([[-0.18998272,  3.68067878]]), array([0.33723228]))

# %%
# Now lets create the same m and b and also y_ip_lor and x_ip_lor for this too to create a line
m_lor = - (lor.coef_[0][0] / lor.coef_[0][1])
b_lor = - (lor.intercept_[0] / lor.coef_[0][1]) 

x_ip_lor = np.linspace(-3,3,X.shape[0])
y_ip_lor = (m_lor*x_ip_lor) + b_lor

# %%
# Now lets plot the same graph and look for the difference between the two lines
plt.figure(figsize=(12,6))
plt.plot(x_ip_lor,y_ip_lor,c='red', label='With Logistic Regression')
plt.plot(x_ip,y_ip,c='blue',label='With Perceptron')
plt.scatter(X[:,0],X[:,1:],c=y)
plt.ylim(-3,2) # This is important without this we are not setting lime limitations and graph will look different
plt.legend()
plt.show()

# %%
'''We can clearly see why Logistic Regression is used as it creates a symmetrical diversion between the classes .

There is also many restrictions in the step function as the values passed by the step function is only 0 or 1 . 
We need such a function that not only used the wrongly classified points as the one to make changes line (pull) 
but also uses the correctly classified point to push away the line from the point . 

Therefore we need to devise such method that can not only perfecly classify but also make the distinguation perfect .'''
# Out:
# 'We can clearly see why Logistic Regression is used as it creates a symmetrical diversion between the classes .\n\nThere is also many restrictions in the step function as the values passed by the step function is only 0 or 1 . \nWe need such a function that not only used the wrongly classified points as the one to make changes line (pull) \nbut also uses the correctly classified point to push away the line from the point . \n\nTherefore we need to devise such method that can not only perfecly classify but also make the distinguation perfect .'

# %%
# To tackle the step functions miss and improve the performance we use a new function called sigmoid function. 
# The sigmoid function helps us to return values between the interval 0 and 1 instead of fixed o and 1. 
# This is served as the probability and we will use it to make the line more perfect for classification .

# %% [markdown]
# ## Sigmoid function

# %%
# Now we will make changes in the class we made so that we can fit using both the methods step and sigmoid
# Note : I explicitly made sure that we can use both the function for better use in future .
class pereceptron:
    def __init__(self,learning_rate=0.1,epochs=1000):
        self.lr = learning_rate
        self.epochs = epochs
        self.coef = None
        self.intercept = None

        # Arrays for m and b in each iteration
        self.m = []
        self.b = []
    def step(self,z):
        return 1 if z>00 else 0
    
    def sigmoid(self,z):
        # This is the sigmoid function
        return 1/(1+(np.exp(-z)))
    

    def fit(self,X,y,method='step'):
        X = np.insert(X,0,1,axis=1) # Creates a column for the coeffecients of w
        w = np.ones(X.shape[1]) # Creates a matrix (1 * n ) where n is the value passed

        # Now iterating over epochs times:
        for i in range(self.epochs):
            # As the formula : Wnew = Wold - lr*(y - y_hat)*X

            # First lets pick the random point index for the iteration
            j = np.random.randint(0,X.shape[0])

            # Second creating y_hat either by step function or sigmoid function
            
            # I added this cause I wanted a function to act upon my method with step function as default
            if method == 'sigmoid':
                y_hat = self.step(np.dot(X[j],w))
            
            else :
                y_hat = self.sigmoid(np.dot(X[j],w))

            # Now lets upadte w value . 
            w = w + self.lr*(y[j] - y_hat)*X[j]

        self.coef = w[1:]
        self.intercept = w[0]
            
        # The process we did explicilty will be done here automatically
        self.m.append(-(w[1]/w[2])) 
        self.b.append(-(w[0]/w[1]))

        return f"Intercept : {w[0]}  Coeffecient : {w[1:]}"
    
    def params(self):
        return self.m,self.b

# %%
perc1 = pereceptron() # Instantiate like usual as seen above

# %%
perc1.fit(X,y,method='sigmoid') # Pass the parameter sigmoid
# Out:
# 'Intercept : 1.3877787807814457e-16  Coeffecient : [-0.0320836   1.01096708]'

# %%
perc1.fit(X,y,method='step') # Pass step,or even if something else is passed the default is step
# Out:
# 'Intercept : 0.3896747214622654  Coeffecient : [-0.39833441  5.14661612]'

# %%
# Again calculating the value of m and b for sigmoid
m_sig = - (perc1.coef[0]/perc1.coef[1])
b_sig = - (perc1.intercept/perc1.coef[1])

# %%
# Again creating a line for plotting the classification
x_ip_sig = np.linspace(-3,3,100)
y_ip_sig = (m_sig*x_ip_sig) + b_sig

# %%
# Now we will compare all the lines we have predicted till now by step , sigmoid and Logistic Regression .
# Same plotting steps as we did earlier 
plt.figure(figsize=(12,6))
plt.plot(x_ip_lor,y_ip_lor,c='red', label='With Logistic Regression')
plt.plot(x_ip_sig,y_ip_sig,c='green', label='With Sigmoid Perceptron')
plt.plot(x_ip,y_ip,c='blue',label='With Step Perceptron')
plt.scatter(X[:,0],X[:,1:],c=y)
plt.ylim(-3,2) # *** #
plt.legend()
plt.show()

# %%
# As we can see the sigmoid is good but still not the best ,
#  so we need even better strategy to be implemented to reach the level of Logistic Regression.

# %%
# Now we will apply gradient descent on this to minimize the error using softmax function

# %% [markdown]
# ## Gradient Descent Algorithm

# %%
# Now we will make our own Gradient Descent Classification model

class GDLogisticRegression:
    def __init__(self,iterations=1000,learning_rate=0.5): # Setting default params 
        # Instantiation of objects
        self.m = None
        self.b = None
        self.iter = iterations
        self.l = learning_rate
        self.coef = None
        self.intercept = None 

    def sigma(self,z):
        return (1/(1 + np.exp(-z)))

    def fit(self,X,y):
        X = np.insert(X,0,1,axis=1) # Inserts column og ones at 0 position on X
        w = np.ones(X.shape[1]) # Make matrix of ones according to nummber of columns in X

        for i in range(self.iter):
            # Finding the value of Yhat
            # Numpy already has the softmax function which is needed for Gradient Descent Algorithm 
            y_hat = self.sigma(np.dot(X,w))

            # Updating the value of w (weights)
            w = w + self.l*(np.dot((y-y_hat),X)/X.shape[0])

            # Updating coef and intercepts
            self.coef = w[1:]
            self.intercept = w[0] 

        return f"Intercept : {w[0]} , Coeffecients : {w[1:]}"

# %%
gdlor = GDLogisticRegression(iterations=5000) # Instantiate the model with iterations = 1000+ , so line will intersect

# %%
gdlor.fit(X,y) # Feed it with inputs and outputs
# Out:
# 'Intercept : 0.8446666157722872 , Coeffecients : [-0.46413187  7.92721085]'

# %%
# Coef and intercepts through object attributes
gdlor.coef , gdlor.intercept
# Out:
# (array([-0.46413187,  7.92721085]), np.float64(0.8446666157722872))

# %%
# Now we will calcualte the m and b value for this
m_gdlor = - (gdlor.coef[0]/gdlor.coef[1])
b_gdlor = - (gdlor.intercept/gdlor.coef[1])

# %%
# Now making a line from this params
x_in_gdlor = np.linspace(-3,3,100)
y_in_gdlor = m_gdlor*x_in_gdlor + b_gdlor

# %%
# Now we will compare all the lines we have predicted till now by step , sigmoid , Logistic Regression and Gradient Descent Algorithm .
# Same plotting steps as we did earlier 
plt.figure(figsize=(12,6))
plt.plot(x_ip_lor,y_ip_lor,c='black', label='With Logistic Regression')
plt.plot(x_in_gdlor,y_in_gdlor,label='Using Gradient Descent ',color='red')
plt.plot(x_ip_sig,y_ip_sig,c='green', label='With Sigmoid Perceptron')
plt.plot(x_ip,y_ip,c='blue',label='With Step Perceptron')
plt.scatter(X[:,0],X[:,1:],c=y)
plt.ylim(-3,2) # *** #
plt.legend()
plt.show()
# The gradietn descent function almost converges with the red line till when the iteration are set hihg (1000+)

# %%
# Actually the algorithm Logistic Regression model of scikit-learn is using softmax function with different solvers and specialized 
# loss function calculated using cross entropy .
