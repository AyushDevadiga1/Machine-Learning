# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing.csv') 
# Note I am using this California Housing Dataset for the sake of understanding the conditions and this is not how we will build model
# in real world

# %%
# For the sake of checking I will drop the categorical column ocean_proximity 
df = df.drop(columns=['ocean_proximity'])

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
# Conditions : 
'''
There must be a linear relationship between X and Y
The columns must be independent to each other and not collinear 
The errors must have a normal distribution graph
When the residuals are plotted it should be heteroskedastic
No correlation of the error points

'''
# Out:
# '\nThere must be a linear relationship between X and Y\nThe columns must be independent to each other and not collinear \nThe errors must have a normal distribution graph\nWhen the residuals are plotted it should be heteroskedastic\nNo correlation of the error points\n\n'

# %%
# Firstly we check whether the columns are collinear or not
# We will use the heatmap and pairplot for this

# %%
sns.heatmap(
                data = df.corr(),
                annot = True,
                cmap='Reds'
)
plt.show()

# %%
# Here we can clearly see that median_house_value is correlated to median_income
# We must drop one of the features If we are further want to train our model
