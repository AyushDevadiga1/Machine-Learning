# %%
# These are basically values use to compare the two groups to whether they are actual difference between them or not ,
# more importantly from same distributions.

# %%
# We can use p values to distinguish between two items , if the p value for both the groups is higher than the threshold
# we assume that the groups are similar and cannot be significantly distributed.
# If the p values are said to be below the threshold then the groups are said to be distinct.

# %%
# We use the threshold of 0.05 to compare p values .
# Not the value : 0.05 means that out of 100 experiments 5 experiments will be false positive that means it will be wrongly guessed.

# %%
# To deal with the false positive we have some statistical methods like false discovery rate.
# If p-value closer to the the threshold then just use power analysis

# %% [markdown]
# ![image.png](attachment:image.png)
