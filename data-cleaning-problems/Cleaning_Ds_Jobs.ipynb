# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
BASE_DIR = os.path.dirname(os.getcwd())
PATH = os.path.join(BASE_DIR,'datasets','Uncleaned_DS_jobs.csv')
df = pd.read_csv(PATH,index_col='index')

# %%
df.shape
# Out:
# (672, 14)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
# Header cleaning
df.columns = df.columns.str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#                job_title               salary_estimate  \
# index
# 0      Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1         Data Scientist  $137K-$171K (Glassdoor est.)
# 2         Data Scientist  $137K-$171K (Glassdoor est.)
# 3         Data Scientist  $137K-$171K (Glassdoor est.)
# 4         Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                          job_description  rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                   company_name       location            headquarters  \
# index
# 0             Healthfirst\n3.1   New York, NY            New York, NY
# 1                 ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
df.tail()
# Out:
#             job_title               salary_estimate  \
# index
# 667    Data Scientist  $105K-$167K (Glassdoor est.)
# 668    Data Scientist  $105K-$167K (Glassdoor est.)
# 669    Data Scientist  $105K-$167K (Glassdoor est.)
# 670    Data Scientist  $105K-$167K (Glassdoor est.)
# 671    Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                          job_description  rating  \
# index
# 667    Summary\n\nWe’re looking for a data scientist ...     3.6
# 668    Job Description\nBecome a thought leader withi...    -1.0
# 669    Join a thriving company that is changing the w...    -1.0
# 670    100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671    Description\n\nThe Data Scientist will be part...     2.7
#
#                     company_name           location     headquarters  \
# index
# 667                TRANZACT\n3.6       Fort Lee, NJ     Fort Lee, NJ
# 668                         JKGT  San Francisco, CA               -1
# ...

# %%
# Notice that there is -1 in many rows this is a sign that data is missing there .

# %%
df.isna().sum() # This is just a scam for now as we know that data is having -1 as na
# Out:
# job_title            0
# salary_estimate      0
# job_description      0
# rating               0
# company_name         0
# location             0
# headquarters         0
# size                 0
# founded              0
# type_of_ownership    0
# industry             0
# sector               0
# revenue              0
# competitors          0
# dtype: int64

# %%
# So to actually get the nan we will do some replacements.
# Twice cause I want to make sure both string and numeric datatype is handled.
# Note : There is no data that might have -1 as valid data here so replacing is fine .

df = df.replace(-1,np.nan)
df = df.replace('-1',np.nan)

# %%
df.isna().sum()/len(df)*100 
# Now this is the reality, or who knows something else may be lurking underneath ; If we will find it later.
# Out:
# job_title             0.000000
# salary_estimate       0.000000
# job_description       0.000000
# rating                7.440476
# company_name          0.000000
# location              0.000000
# headquarters          4.613095
# size                  4.017857
# founded              17.559524
# type_of_ownership     4.017857
# industry             10.565476
# sector               10.565476
# revenue               4.017857
# competitors          74.553571
# dtype: float64

# %%
# For further steps I use data wrangler for EDA

# %%
df['salary_estimate'].str.split(" ")[0][0]
# Out:
# '$137K-$171K'

# %%
df['salary_estimate'] = df['salary_estimate'].str.split(" ").str[0] # Some Standard Cleaning for Salary Estimate

# %%
df.sample()
# Out:
#             job_title salary_estimate  \
# index
# 499    Data Scientist      $95K-$119K
#
#                                          job_description  rating  \
# index
# 499    Job Overview: The Data Scientist is a key memb...     NaN
#
#          company_name           location headquarters size  founded  \
# index
# 499    Hatch Data Inc  San Francisco, CA          NaN  NaN      NaN
#
#       type_of_ownership industry sector revenue competitors
# index
# 499                 NaN      NaN    NaN     NaN         NaN

# %%
# There is strangely the rating again specified in the company name so we are gonna remove it . 
df['company_name'].str.split('\n').str[0]
# Out:
# index
# 0               Healthfirst
# 1                   ManTech
# 2            Analysis Group
# 3                   INFICON
# 4        Affinity Solutions
#                ...
# 667                TRANZACT
# 668                    JKGT
# 669              AccessHope
# 670    ChaTeck Incorporated
# 671           1-800-Flowers
# Name: company_name, Length: 672, dtype: object

# %%
df['company_name'] = df['company_name'].str.split('\n').str[0]

# %%
df.sample(3)
# Out:
#                    job_title salary_estimate  \
# index
# 98     Senior Data Scientist      $99K-$132K
# 469         VP, Data Science       $31K-$56K
# 617           Data Scientist      $87K-$141K
#
#                                          job_description  rating company_name  \
# index
# 98     About Us\n\nAt GutCheck, we pioneered agile ma...     3.8     GutCheck
# 469    We are looking for a VP, Data Science to lead ...     3.9   7Park Data
# 617    Data Engineer\n\nDescription\nUST Global is lo...     4.2   UST Global
#
#            location     headquarters                 size  founded  \
# index
# 98       Denver, CO       Denver, CO  51 to 200 employees   2009.0
# 469    New York, NY     New York, NY  51 to 200 employees   2012.0
# 617     Atlanta, GA  Aliso Viejo, CA     10000+ employees   1999.0
#
#        type_of_ownership                 industry                  sector  \
# index
# 98     Company - Private  Advertising & Marketing       Business Services
# ...

# %%
# Found another thing now that the revenue column have rows with value : Unknown / Non-Applicable which are also nan so we must handle this too.

# %%
df['revenue'] = df['revenue'].replace('Unknown / Non-Applicable',np.nan)

# %%
df.isna().sum()/len(df)*100  
# As we can see the Revenue null values have spiked .
# Out:
# job_title             0.000000
# salary_estimate       0.000000
# job_description       0.000000
# rating                7.440476
# company_name          0.000000
# location              0.000000
# headquarters          4.613095
# size                  4.017857
# founded              17.559524
# type_of_ownership     4.017857
# industry             10.565476
# sector               10.565476
# revenue              35.714286
# competitors          74.553571
# dtype: float64

# %%
df.sample(3)
# Out:
#                                          job_title       salary_estimate  \
# index
# 167                            Senior Data Analyst           $101K-$165K
# 306                                 Data Scientist  $145K-$225K(Employer
# 102    Health Data Scientist - Biomedical/Biostats            $99K-$132K
#
#                                          job_description  rating  \
# index
# 167    Secure our Nation, Ignite your Future\n\nJob S...     4.2
# 306    Long term. 6 months contract to hire. Open to ...     3.9
# 102    Evidation Health is a new kind of health and m...     4.1
#
#            company_name           location   headquarters  \
# index
# 167            Autodesk  San Francisco, CA    Herndon, VA
# 306    ALTA IT Services       Woodlawn, MD  Rockville, MD
# 102           Evidation  Santa Barbara, CA  San Mateo, CA
#
#                           size  founded  type_of_ownership  \
# index
# 167    5001 to 10000 employees   1968.0   Company - Public
# ...
