# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Swarm plots can be used to plot categorical and continous numeric value

# %%
from sklearn.datasets import load_linnerud

# %%
df = pd.read_csv('Titanic-dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ax = sns.swarmplot(
    data = df,
    x = 'Pclass',
    y = 'Age',
    size = 4,
    hue = 'Sex'
)

# %%
ax1 = sns.stripplot(
    data = df,
    x = 'Pclass',
    y = 'Age',
    size = 5,
    hue = 'Sex',
    # jitter = True,
    palette='viridis' # plasma , RdBu , tab20 , Accent
)

# %%
ax2 = sns.countplot(
    data = df,
    x = 'Survived',
    hue = 'Sex',
    palette='tab20',
    stat = 'percent'
)

# %%
# sns.set_theme('notebook') # Set theme
# sns.set_style('ticks') # Set style
plt.figure(figsize=(12,6))
ax3 = sns.scatterplot(
    data = df,
    x = 'Age',
    y = 'Fare',
    hue = 'Embarked',
    style = 'Survived',
    palette='tab10' 
)
# plt.xlim(0,100)  #xlimits
plt.ylim(0,600)  #ylimits
plt.show()

# %%
# We use histplot to visualize continous variables 
plt.figure(figsize=(13,6))
sns.histplot(
    data = df ,
    x = 'Age',
    # binrange=(0,100),
    # bins = 25,
    legend=True,
    hue = 'Sex',
    thresh = 1,
    kde = True,
    multiple = 'stack',
    palette = 'tab10',
    # element = 'bars'
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Kdeplot is similar to histplot and is used to estimate the density of the variable 
plt.figure(figsize=(12,5))
sns.kdeplot(
    data = df ,
    x = 'Age',
    legend=True,
    hue = 'Pclass',
    fill = True,
    alpha = 0.35,
    palette = 'tab10',
)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Jointplot used to use two analyze variables together using two techniques consequently 
sns.jointplot(
    data = df,
    x = 'Age',
    y = 'Fare',
    kind = 'reg', # 'scatter', 'kde', 'hist', 'hex', 'reg', 'resid'
)

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Outcome
# 0     0.627   50        1
# 1     0.351   31        0
# 2     0.672   32        1
# 3     0.167   21        0
# 4     2.288   33        1

# %%
# We use joint plots to get a overall view of the dataset using any univarate plotting method 
sns.pairplot(
    data = data[['Glucose' , 'BloodPressure' , 'BMI' , 'Age' , 'Outcome']], # Use with caution as loading many columns together takes time
    kind = 'reg', # We can use many other types : ['scatter', 'kde', 'hist', 'reg']
    hue = 'Outcome'
)

# %%
# Works with other plots to make comprehensive analysis.
sns.rugplot(
    data = data,
    x = 'Insulin',
    height = 0.5,
    hue = 'Outcome',
    palette = ['yellow' , 'blue'],
)
# Out:
# <Axes: xlabel='Insulin'>

# %%
# To analyze relations between categorical and continous numerical we can use barplot
plt.figure(figsize=(12,6))
sns.barplot(
    data = df,
    x = 'Embarked', # Categorical
    y = 'Fare', # Continous
    hue = 'Sex',
    # estimator = np.var, # We can pass any numpy function as an estimator as we need.
    palette = 'tab20'
)
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Outcome
# 0     0.627   50        1
# 1     0.351   31        0
# 2     0.672   32        1
# 3     0.167   21        0
# 4     2.288   33        1

# %%
# Boxplot to compare distribution and outlier analysis for variable/s which are categorical and continous.
plt.figure(figsize=(12,6))
sns.boxplot(
    data = df,
    x = 'Pclass', # Categorical 
    y = 'Age', # Continous
    hue = 'Survived', # Categorical
    palette = ['cyan','violet'],
    width = 0.8,
    linecolor = 'black',
    saturation = 0.5
)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
loan_data = pd.read_csv('loan_data.csv')

# %%
loan_data.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
# Violin plots
plt.figure(figsize=(10,6))
sns.violinplot(
    data = loan_data,
    x = 'person_education',
    y = 'loan_amnt',
    hue = 'person_gender',
    palette = ['blue','green'],
    saturation = 1,
    fill = False,
)
# Out:
# <Axes: xlabel='person_education', ylabel='loan_amnt'>
